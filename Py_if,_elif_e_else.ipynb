# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasdesa1007-dot/1-atividade-em-python/blob/main/Py_if%2C_elif_e_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota_float = round(float(input("Qual sua nota: ")))
if nota_float >= 6:
 print("Aprovado")
elif nota_float >= 5:
 print("recuperaçao")
else:
 print("reprovado")
# Out:
# Qual sua nota: 10
# Aprovado

# %%
idade = 18
idade = int(input("Qual sua idade: "))
if idade >= 18:
 print("Maior de idade")
else:
 print("Menor de idade")
# Out:
# Qual sua idade: 15
# Menor de idade

# %%
numero = int(input("Me diga um numero para saber se ele e positivo ou negativo: "))
if numero >= 0:
  print("numero positivo")
else:
  print("numero negativo")
# Out:
# Me diga um numero para saber se ele e positivo ou negativo: 20
# numero positivo

# %%
numero = int(input("Me fale um numero que voce queira saber se e impar ou par: "))
if numero % 2 == 0:
  print("Esse numero e par")
else:
  print("Esse e impar")
# Out:
# Me fale um numero que voce queira saber se e impar ou par: 244
# Esse numero e par

# %%
num1 = int(input("Digite um numero: "))
num2 = int(input("Digite outro numero: "))
if num1 > num2:
 print(f"O numero {num1} é maior que o {num2}")
else:
  print(f"O numero {num2} é maior que o {num1}")
# Out:
# Digite um numero: 20
# Digite outro numero: 7
# O numero 20 é maior que o 7

# %%
temp = int(input("Qual a temperatura de hoje: "))
if temp >= 27:
  print("Rapaz mas ta calor em.")
elif temp >= 20:
  print("Clima bom, nem calor e nem frio.")
else:
  print("Rapaz ta frio em.")
# Out:
# Qual a temperatura de hoje: 19
# Rapaz ta frio em.

# %%
usuario_correto = "aluno2026"
senha_correta = "dsm2026"
usuario = input("Digite seu nome de usuario: ")
if  usuario != usuario_correto:
   print("Usuario incorreto")
else:
  print("Agora digite sua senha no campo abaixo: ")
senha = input("Senha: ")
if senha == senha_correta:
     print("Seu login foi concluido seja bem-vindo!")
else:
     print("Senha incorreta!")
# Out:
# Digite seu nome de usuario: lucas
# Usuario incorreto
# Senha: bals
# Senha incorreta!

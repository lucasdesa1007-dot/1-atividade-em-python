# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasdesa1007-dot/1-atividade-em-python/blob/main/Py_Lista_de_algoritimos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Olá, qual seu nome: ")
print ("Olá, " + nome)
# Out:
# Olá, qual seu nome: Lucas
# Olá, Lucas

# %%
dia = int(input("Opa tudo bem se sabe que dia é hoje? "))
print ("Vlw ai so agradece")
# Out:
# Opa tudo bem se sabe que dia é hoje? 18
# Vlw ai so agradece

# %%
lanche_str = input("Olá tudo bem quanto ta o lanche? ")
lanche = float(lanche_str.replace(',','.'))
bebida_str = input("E a bebida? ")
bebida = float(bebida_str.replace(',','.'))
resul_soma = lanche + bebida
resul_soma = str(resul_soma)
print("Tudo fica R$ " + resul_soma)
# Out:
# Olá tudo bem quanto ta o lanche? 20.00
# E a bebida? 12.99
# Tudo fica R$ 32.99

# %%
idade1 = int(input("Eae Lucas qual sua idade: "))
idade2 = int(input("Olá Maria qual e sua idade: "))
idade3 = int(input("Eae Pedro qual sua idade: "))
soma_idade = idade1 + idade2 + idade3
media = soma_idade / 3
media = int(media)
print(f"A media de idade entre eles é de " + (str(media)) + " anos")
# Out:
# Eae Lucas qual sua idade: 20
# Olá Maria qual e sua idade: 56
# Eae Pedro qual sua idade: 12
# A media de idade entre eles é de 29 anos

# %%
altura1_str = str(input("Olá Lucas qual sua altura: "))
altura1 = float(altura1_str.replace(',','.'))
altura2_str = str(input("Olá Maria qual sua altura: "))
altura2 = float(altura2_str.replace(',','.'))
altura3_str = str(input("Eae Pedro qual sua altura: "))
altura3 = float(altura3_str.replace(',','.'))
soma_altura = altura1 + altura2 + altura3
media = soma_altura / 3
print(f"A media de altura entre eles é de {media:.2f} M")
# Out:
# Olá Lucas qual sua altura:1.90
# Olá Maria qual sua altura:1.67
# Eae Pedro qual sua altura:2.10
# A media de altura entre eles é de 1.89 M

# %%
produto1_str = str(input("Olá Lucas qual o valor da coca-cola no mercado: "))
produto1 = float(produto1_str.replace(',','.'))
produto2_str = str(input("Olá Maria qual o valor da coca-cola no mercadinho da sua rua: "))
produto2 = float(produto2_str.replace(',','.'))
produto3_str = str(input("Eae Pedro qual o valor da coca-cola na adega: "))
produto3 = float(produto3_str.replace(',','.'))
soma_produto = produto1 + produto2 + produto3
media = soma_produto / 3
print(f"A media do preço da coca-cola entre os lugares de venda é de R$ {media:.2f}")
# Out:
# Olá Lucas qual o valor da coca-cola no mercado: 12.99
# Olá Maria qual o valor da coca-cola no mercadinho da sua rua: 10,50
# Eae Pedro qual o valor da coca-cola na adega: 10.00
# A media do preço da coca-cola entre os lugares de venda é de R$ 11.16

# %%
peso1_str = str(input("Olá Lucas qual o seu peso: "))
peso1 = float(peso1_str.replace(',','.'))
peso2_str = str(input("Olá Maria qual o seu peso: "))
peso2 = float(peso2_str.replace(',','.'))
peso3_str = str(input("Eae Pedro qual o seu peso: "))
peso3 = float(peso3_str.replace(',','.'))
soma_peso = peso1 + peso2 + peso3
media = soma_peso / 3
print(f"A media do peso entre os lugares de venda é de {media:.2f} Kg")
# Out:
# Olá Lucas qual o seu peso: 79.90
# Olá Maria qual o seu peso: 110.90
# Eae Pedro qual o seu peso: 76.67
# A media do peso entre os lugares de venda é de 89.16 Kg

# %%
ano_atual = int(input("Olá qual ano que é: "))
ano_nasc = int(input("Olá qual ano voce nasceu: "))
idade = ano_atual - ano_nasc
idade = str(idade)
print("Sua idade é " + idade)
# Out:
# Olá qual ano que é: 2026
# Olá qual ano voce nasceu: 2007
# Sua idade é 19

# %%
ano_atual = int(input("Olá qual ano que é: "))
idade = int(input("Qual sua idade: "))
ano_nasc = ano_atual - idade
ano_nasc = str(ano_nasc)
print("O ano que voce nasceu foi em " + ano_nasc)
# Out:
# Olá qual ano que é: 2026
# Qual sua idade: 19
# O ano que voce nasceu foi em 2007

# %%
nome = str(input("Olá qual seu nome: "))
idade = str(input("Qual sua idade: "))
input("Olá " + nome + ", entao voce tem " + idade + " correto? " )
print("Ok tudo certo, seja bem-vindo em nosso parque")
# Out:
# Olá qual seu nome: lucas
# Qual sua idade: 19
# Olá lucas, entao voce tem 19 correto? sim
# Ok tudo certo, seja bem-vindo em nosso parque
